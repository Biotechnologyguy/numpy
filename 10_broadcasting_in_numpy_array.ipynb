# %%
import numpy as np

# %%
# When do we get this error?

a1 = np.array([1,2,3,4])
a2 = np.array([1,2,3])

print(np.add(a1, a2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       3 a1 = np.array([1,2,3,4])
#       4 a2 = np.array([1,2,3])
# ----> 6 print(np.add(a1, a2))
#
# ValueError: operands could not be broadcast together with shapes (4,) (3,)

# %% [markdown]
# We should have either same dimension or second condition as below : (having 1)
#
# ![image.png](attachment:73a0c97d-4684-4f7f-8a8e-8c348fcb3bc5.png)

# %%
# Seccond condition

a3 = np.array([1,2,3,4])
a4 = np.array([[1],[2],[3]])

print(a3)
print()
print(a4)
print()
print(np.add(a3, a4))
print()
# Out:
# [1 2 3 4]
#
# [[1]
#  [2]
#  [3]]
#
# [[2 3 4 5]
#  [3 4 5 6]
#  [4 5 6 7]]

# %%
# Seccond condition

a3 = np.array([[1],[2],[3]])
a4 = np.array([[1,3,4],[2,1,8],[1,2,3]])

print(f"Shape of a3 : {a3.shape}")
print(f"Shape of a4 : {a4.shape}")

print(a3)
print()
print(a4)
print()
print(np.add(a3, a4))
print()
# Out:
# Shape of a3 : (3, 1)
# Shape of a4 : (3, 3)
# [[1]
#  [2]
#  [3]]
#
# [[1 3 4]
#  [2 1 8]
#  [1 2 3]]
#
# [[ 2  4  5]
#  [ 4  3 10]
#  [ 4  5  6]]
